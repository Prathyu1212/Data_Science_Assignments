# %% [markdown]
# ### Import Necessary data

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import data

# %%
zoo_catogery = pd.read_csv('Zoo.csv')
zoo_catogery
# Out:
#     animal name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark     1         0     0     1         0        0         1
# 1      antelope     1         0     0     1         0        0         0
# 2          bass     0         0     1     0         0        1         1
# 3          bear     1         0     0     1         0        0         1
# 4          boar     1         0     0     1         0        0         1
# ..          ...   ...       ...   ...   ...       ...      ...       ...
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
#      toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# ...

# %%
zoo_catogery.head(50)
# Out:
#    animal name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0     aardvark     1         0     0     1         0        0         1
# 1     antelope     1         0     0     1         0        0         0
# 2         bass     0         0     1     0         0        1         1
# 3         bear     1         0     0     1         0        0         1
# 4         boar     1         0     0     1         0        0         1
# 5      buffalo     1         0     0     1         0        0         0
# 6         calf     1         0     0     1         0        0         0
# 7         carp     0         0     1     0         0        1         0
# 8      catfish     0         0     1     0         0        1         1
# 9         cavy     1         0     0     1         0        0         0
# 10     cheetah     1         0     0     1         0        0         1
# 11     chicken     0         1     1     0         1        0         0
# ...

# %% [markdown]
# ### Data Understanding

# %%
zoo_catogery.shape
# Out:
# (101, 18)

# %%
zoo_catogery.dtypes
# Out:
# animal name    object
# hair            int64
# feathers        int64
# eggs            int64
# milk            int64
# airborne        int64
# aquatic         int64
# predator        int64
# toothed         int64
# backbone        int64
# breathes        int64
# venomous        int64
# fins            int64
# legs            int64
# tail            int64
# domestic        int64
# catsize         int64
# type            int64
# dtype: object

# %%
zoo_catogery.isna().sum()
# Out:
# animal name    0
# hair           0
# feathers       0
# eggs           0
# milk           0
# airborne       0
# aquatic        0
# predator       0
# toothed        0
# backbone       0
# breathes       0
# venomous       0
# fins           0
# legs           0
# tail           0
# domestic       0
# catsize        0
# type           0
# dtype: int64

# %%
zoo_catogery.drop('animal name',axis=1,inplace=True)

# %%
zoo_catogery.dtypes
# Out:
# hair        int64
# feathers    int64
# eggs        int64
# milk        int64
# airborne    int64
# aquatic     int64
# predator    int64
# toothed     int64
# backbone    int64
# breathes    int64
# venomous    int64
# fins        int64
# legs        int64
# tail        int64
# domestic    int64
# catsize     int64
# type        int64
# dtype: object

# %% [markdown]
# ### Model Building

# %%
X = zoo_catogery.drop(labels=['type'],axis=1)
y = zoo_catogery[['type']]

# %%
X.shape,y.shape
# Out:
# ((101, 16), (101, 1))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.15,random_state=12,stratify=y)

# %%
X_train.shape,y_train.shape
# Out:
# ((85, 16), (85, 1))

# %%
X_test.shape,y_test.shape
# Out:
# ((16, 16), (16, 1))

# %% [markdown]
# ### Model Training

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier(n_neighbors=3)
knn_classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### Model Testing

# %%
y_pred = knn_classifier.predict(X_test)
y_pred
# Out:
# array([7, 2, 1, 7, 1, 2, 2, 1, 1, 1, 4, 5, 6, 2, 4, 1], dtype=int64)

# %% [markdown]
# ### Model evaluation

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score

# %%
print('accuracy_score:' ,accuracy_score(y_test,y_pred))
# Out:
# accuracy_score: 0.9375

# %% [markdown]
# #### standardizing the input features to see the changes in accuracy

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
std_scaler.fit(zoo_catogery.drop('type',axis=1))
scaled_features = std_scaler.transform(zoo_catogery.drop('type',axis=1))
X_scaled = pd.DataFrame(scaled_features,columns=zoo_catogery.columns[:-1])

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier(n_neighbors=3)
knn_classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
print('accuracy_score:' ,accuracy_score(y_test,y_pred))
# Out:
# accuracy_score: 0.9375

# %% [markdown]
# #### To choose optimal number of Neighbours

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
cv_scores = []

for i in range(1,30,3):
    knn_model = KNeighborsClassifier(n_neighbors = i)
    cross_val_scores = cross_val_score(estimator=knn_model,X=X_scaled,y=y,cv=5)
    cv_scores.append(cross_val_scores.mean())

# %%
cv_scores
# Out:
# [0.9504761904761905,
#  0.9204761904761906,
#  0.9200000000000002,
#  0.8704761904761906,
#  0.8604761904761904,
#  0.870952380952381,
#  0.8614285714285714,
#  0.8219047619047618,
#  0.8019047619047619,
#  0.7823809523809524]

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(range(1,31,3),cv_scores)
plt.title('neighbors vs cvscore')
plt.xlabel('neighbors')
plt.ylabel('mean accuracy')
plt.show()

# %%
max(cv_scores)
# Out:
# 0.9504761904761905

# %% [markdown]
# **One neighbor is optimal for the data with a accuracy of 0.9504**
